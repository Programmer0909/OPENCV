# %% [markdown]
# <a href="https://colab.research.google.com/github/Programmer0909/OPENCV/blob/master/OpenCV_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# # READING AND DISPLAYING IMAGE

# %%
image = cv2.imread("/content/castara-tobago.jpeg")

# %%
plt.imshow(cv2.cvtColor(image , cv2.COLOR_BGR2RGB) )
plt.axis("off")
plt.show()

# %%
def show_img(title="" , image = None):
    from google.colab.patches import cv2_imshow
    plt.imshow(cv2.cvtColor(image , cv2.COLOR_BGR2RGB) )
    plt.axis("off")
    plt.title(title)
    plt.show()
    print('Height of Image: {} pixels'.format(int(image.shape[0])))
    print('Width of Image: {} pixels'.format(int(image.shape[1])))
    print('Depth of Image: {} colors components'.format(int(image.shape[2])))

# %%
show_img("First Image" , image)
# Out:
# Height of Image: 1600 pixels
# Width of Image: 1200 pixels
# Depth of Image: 3 colors components

# %% [markdown]
# # Save image

# %%
cv2.imwrite("Output.jpg", image)
# Out:
# True

# %%
print('Height of Image: {} pixels'.format(int(image.shape[0])))
print('Width of Image: {} pixels'.format(int(image.shape[1])))
print('Depth of Image: {} colors components'.format(int(image.shape[2])))
# Out:
# Height of Image: 1600 pixels
# Width of Image: 1200 pixels
# Depth of Image: 3 colors components
